# %% [markdown]
# Praktikum: Toko Dorayaki Doraemon

# %%
#1. Meminta masukan dari user berupa nama makanan, nama karakter, dan kata sifat.
nama_makanan = input("Nama makanan:")
nama_karakter = input("Nama karakter:")
kata_sifat = input("Kata sifat:")
# Out:
# Nama makanan: Dorayaki
# Nama karakter: Doraemon
# Kata sifat: Dahsyat

# %%
#2. Menggabungkan ketiga variabel menjadi satu string nama toko.
nama_toko = nama_makanan + " " + nama_karakter + " " + kata_sifat
print("Nama toko:", nama_toko)
# Out:
# Nama toko: Dorayaki Doraemon Dahsyat

# %%
#3. Menggumpulkan modal.
modal_doraemon = 555000
modal_nobita = 333000
modal_shizuka = 222000

# %%
#4. Menghitung total  modal.
total_modal = modal_doraemon + modal_nobita + modal_shizuka
print("Total modal:", total_modal)
# Out:
# Total modal: 1110000

# %%
#5. Membuat variabel dan menghitung total pendapatan pada bulan pertama.
jumlah_dorayaki = 350
harga_dorayaki = 5000
total_pendapatan = jumlah_dorayaki * harga_dorayaki
print("Total pendapatan pada bulan pertama:", total_pendapatan)
# Out:
# Total pendapatan pada bulan pertama: 1750000

# %%
#6. Menghitung keuntungan pada bulan pertama.
keuntungan = total_pendapatan - total_modal

# %%
#7. Mengidentifikasi jenis error dan menuliskan perbaikan kode yang benar.
#penyebab error: tidak ada tanda koma atau tandda tambah yang memisahkan string dan variabel.
print("Keuntungan total adalah:", keuntungan)
# Out:
# Keuntungan total adalah: 640000
